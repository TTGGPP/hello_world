# %% [markdown]
# ## 원본 엑셀 파일, 컬럼 조정 후 csv 파일로 전환, 저장

# %%
import os
import re
import numpy as np
import pandas as pd

# %%
# 원본 엑셀 파일 리스트 읽어오기, raw-files 폴더
RAW_FILES_PATH = 'apt-raw-files'

raw_files = os.listdir(RAW_FILES_PATH)
raw_files = [ f'{RAW_FILES_PATH}/{r}' for r in raw_files ]
raw_files[0], len(raw_files)
# Out:
# ('apt-raw-files/아파트(매매)_실거래가_201208.xlsx', 96)

# %%
# 원본 엑셀 데이터 컬럼명
RAW_FILE_COLUMNS = ['region', 'street_num', 'street_num1', 'street_num2',
                    'apt_name', 'apt_size', 'contract_yymm', 'contract_dd',
                    'contract_price', 'apt_floor','completion_year','street_name']

# %%
# data-files 폴더 만들기
DATA_FILES_PATH = 'apt-data-files'

if not(os.path.isdir(DATA_FILES_PATH)):
    os.makedirs(os.path.join(DATA_FILES_PATH))

# %%
# 기록할 파일 리스트 만들기
data_files = []
for rf in raw_files:
    p = re.compile('[0-9]+')
    date_name = p.findall(rf)
    data_files.append(f'{DATA_FILES_PATH}/{date_name[0]}.csv')

# files_zip = zip(raw_files, data_files)
data_files[0], len(data_files)
# Out:
# ('apt-data-files/201208.csv', 96)

# %%
# 수정 CSV 데이터 컬럼명
DATA_FILE_COLUMNS = ['region', 'region_sub', 'apt_name', 'apt_size',
                     'apt_floor', 'contract_date', 'contract_price',
                     'completion_year', 'street_num', 'street_name']

# region = 도, 광역시, 특별시
# region_sub = 시군구
# apt_name = 단지명
# apt_size = 전용면적
# apt_floor = 층
# contract_date = 계약년월일
# contract_price = 거래금액
# completion_year = 건축년도
# street_num = 번지
# street_name = 도로명

# %%
# 엑셀 파일 로드 테스트
fileD = pd.read_excel(raw_files[0], index_col=None, header=None, skiprows=17)
fileD.columns = RAW_FILE_COLUMNS

fileD.info()
fileD.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26054 entries, 0 to 26053
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   region           26054 non-null  object
#  1   street_num       26054 non-null  object
#  2   street_num1      26054 non-null  int64
#  3   street_num2      26054 non-null  int64
#  4   apt_name         26054 non-null  object
#  5   apt_size         26054 non-null  float64
#  6   contract_yymm    26054 non-null  int64
#  7   contract_dd      26054 non-null  int64
#  8   contract_price   26054 non-null  object
#  9   apt_floor        26054 non-null  int64
#  10  completion_year  26054 non-null  int64
#  11  street_name      26054 non-null  object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 2.4+ MB
#         region street_num  street_num1  street_num2      apt_name  apt_size  \
# 0  강원도 강릉시 견소동        202          202            0          송정한신    84.945
# 1  강원도 강릉시 견소동        202          202            0          송정한신    59.800
# 2  강원도 강릉시 견소동        202          202            0          송정한신    59.800
# 3  강원도 강릉시 견소동        289          289            0  송정해변신도브래뉴아파트    84.990
# 4  강원도 강릉시 견소동        289          289            0  송정해변신도브래뉴아파트    84.990
#
#    contract_yymm  contract_dd  contract_price  apt_floor  completion_year  \
# 0         201208           24          13,000          5             1997
# 1         201208           27           8,500         15             1997
# 2         201208           31           6,000          1             1997
# 3         201208            8          15,000          7             2005
# 4         201208            9          16,500          9             2005
#
#     street_name
# 0   경강로2539번길 8
# 1   경강로2539번길 8
# 2   경강로2539번길 8
# 3  경강로2539번길 22
# 4  경강로2539번길 22

# %%
# 컬럼 추가 및 데이터 수정 함수
def buildRawD(D=None):
    if D is None:
        return 0

    region_str = D['region'].split(" ", 1)
    
    D['region'] = region_str[0]
    D['region_sub'] = region_str[1]

    D['apt_size'] = f'{D["apt_size"]:#.02f}'

    # yyyy-mm-dd 형식 변환
    yymm = str(D['contract_yymm'])
    D['contract_date'] = f'{yymm[:4]}-{yymm[4:]}-{D["contract_dd"]:#02d}'
    
    # ',' 제거, (만원) -> 0000 추가
    D['contract_price'] = D['contract_price'].replace(',', '') + '0000'

    return D

# %%
# 원본 데이터 수정
rawD = fileD.apply(buildRawD, axis=1)

rawD.info()
rawD.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26054 entries, 0 to 26053
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   region           26054 non-null  object
#  1   street_num       26054 non-null  object
#  2   street_num1      26054 non-null  int64
#  3   street_num2      26054 non-null  int64
#  4   apt_name         26054 non-null  object
#  5   apt_size         26054 non-null  object
#  6   contract_yymm    26054 non-null  int64
#  7   contract_dd      26054 non-null  int64
#  8   contract_price   26054 non-null  object
#  9   apt_floor        26054 non-null  int64
#  10  completion_year  26054 non-null  int64
#  11  street_name      26054 non-null  object
#  12  region_sub       26054 non-null  object
#  13  contract_date    26054 non-null  object
# dtypes: int64(6), object(8)
# memory usage: 2.8+ MB
#   region street_num  street_num1  street_num2      apt_name apt_size  \
# 0    강원도        202          202            0          송정한신    84.94
# 1    강원도        202          202            0          송정한신    59.80
# 2    강원도        202          202            0          송정한신    59.80
# 3    강원도        289          289            0  송정해변신도브래뉴아파트    84.99
# 4    강원도        289          289            0  송정해변신도브래뉴아파트    84.99
#
#    contract_yymm  contract_dd     contract_price  apt_floor  completion_year  \
# 0         201208           24          130000000          5             1997
# 1         201208           27           85000000         15             1997
# 2         201208           31           60000000          1             1997
# 3         201208            8          150000000          7             2005
# 4         201208            9          165000000          9             2005
#
#     street_name region_sub contract_date
# 0   경강로2539번길 8    강릉시 견소동    2012-08-24
# 1   경강로2539번길 8    강릉시 견소동    2012-08-27
# 2   경강로2539번길 8    강릉시 견소동    2012-08-31
# 3  경강로2539번길 22    강릉시 견소동    2012-08-08
# 4  경강로2539번길 22    강릉시 견소동    2012-08-09

# %%
# 필요 데이터 선택 및 컬럼 재배치, 데이터 변환하기
dataD = rawD.loc[:, DATA_FILE_COLUMNS]

dataD.info()
dataD.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26054 entries, 0 to 26053
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   region           26054 non-null  object
#  1   region_sub       26054 non-null  object
#  2   apt_name         26054 non-null  object
#  3   apt_size         26054 non-null  object
#  4   apt_floor        26054 non-null  int64
#  5   contract_date    26054 non-null  object
#  6   contract_price   26054 non-null  object
#  7   completion_year  26054 non-null  int64
#  8   street_num       26054 non-null  object
#  9   street_name      26054 non-null  object
# dtypes: int64(2), object(8)
# memory usage: 2.0+ MB
#   region region_sub      apt_name apt_size  apt_floor contract_date  \
# 0    강원도    강릉시 견소동          송정한신    84.94          5    2012-08-24
# 1    강원도    강릉시 견소동          송정한신    59.80         15    2012-08-27
# 2    강원도    강릉시 견소동          송정한신    59.80          1    2012-08-31
# 3    강원도    강릉시 견소동  송정해변신도브래뉴아파트    84.99          7    2012-08-08
# 4    강원도    강릉시 견소동  송정해변신도브래뉴아파트    84.99          9    2012-08-09
#
#       contract_price  completion_year street_num   street_name
# 0          130000000             1997        202   경강로2539번길 8
# 1           85000000             1997        202   경강로2539번길 8
# 2           60000000             1997        202   경강로2539번길 8
# 3          150000000             2005        289  경강로2539번길 22
# 4          165000000             2005        289  경강로2539번길 22

# %%
# data-files 폴더에 수정한 데이터 csv 파일 저장
dataD.to_csv(data_files[0], mode='w', header=True, index=False)

# %%
# 파일 일괄 수정 및 저장 함수
def make_new_files(files_zip):
    
    total_count = 0
    for raw_path, data_path in files_zip:
        fileD = pd.read_excel(raw_path, index_col=None, header=None, skiprows=17)
        fileD.columns = RAW_FILE_COLUMNS
        
        rawD = fileD.apply(buildRawD, axis=1)
        dataD = rawD.loc[:, DATA_FILE_COLUMNS]

        dataD.to_csv(data_path, mode='w', header=True, index=False)

        data_count = len(dataD)
        total_count += data_count
        print(f'complete {data_path}, data count: {data_count}')
    
    print(f'total data count: {total_count}')

# %%
# 일괄 파일 만들기
# data-files 폴더 지우고 실행
# 소요 시간 3시간 15분!!!
# total data count: 4800528

# make_new_files(zip(raw_files, data_files))
# Out:
# complete apt-data-files/201208.csv, data count: 26054
# complete apt-data-files/201209.csv, data count: 34032
# complete apt-data-files/201210.csv, data count: 45854
# complete apt-data-files/201211.csv, data count: 42309
# complete apt-data-files/201212.csv, data count: 37772
# complete apt-data-files/201301.csv, data count: 31650
# complete apt-data-files/201302.csv, data count: 38174
# complete apt-data-files/201303.csv, data count: 53797
# complete apt-data-files/201304.csv, data count: 56387
# complete apt-data-files/201305.csv, data count: 53053
# complete apt-data-files/201306.csv, data count: 49828
# complete apt-data-files/201307.csv, data count: 31438
# complete apt-data-files/201308.csv, data count: 41045
# complete apt-data-files/201309.csv, data count: 51796
# complete apt-data-files/201310.csv, data count: 61687
# complete apt-data-files/201311.csv, data count: 45881
# complete apt-data-files/201312.csv, data count: 48839
# complete apt-data-files/201401.csv, data count: 48870
# complete apt-data-files/201402.csv, data count: 58396
# complete apt-data-files/201403.csv, data count: 62068
# complete apt-data-files/201404.csv, data count: 47872
# complete apt-data-files/201405.csv, data count: 43663
# complete apt-data-files/201406.csv, data count: 44359
# complete apt-data-files/201407.csv, data count: 50171
# complete apt-data-files/201408.csv, data count: 59766
# complete apt-data-files/201409.csv, data count: 66036
# complete apt-data-files/201410.csv, data count: 64274
# complete apt-data-files/201411.csv, data count: 48622
# complete apt-data-files/201412.csv, data count: 46394
# complete apt-data-files/201501.csv, data count: 61598
# complete apt-data-files/201502.csv, data count: 55893
# complete apt-data-files/201503.csv, data count: 87137
# complete apt-data-files/201504.csv, data count: 71654
# complete apt-data-files/201505.csv, data count: 60953
# complete apt-data-files/201506.csv, data count: 62737
# complete apt-data-files/201507.csv, data count: 61775
# complete apt-data-files/201508.csv, data count: 52133
# complete apt-data-files/201509.csv, data count: 55654
# complete apt-data-files/201510.csv, data count: 64446
# complete apt-data-files/201511.csv, data count: 47218
# complete apt-data-files/201512.csv, data count: 36855
# complete apt-data-files/201601.csv, data count: 35629
# complete apt-data-files/201602.csv, data count: 36424
# complete apt-data-files/201603.csv, data count: 53434
# complete apt-data-files/201604.csv, data count: 53500
# complete apt-data-files/201605.csv, data count: 51356
# complete apt-data-files/201606.csv, data count: 59963
# complete apt-data-files/201607.csv, data count: 59136
# complete apt-data-files/201608.csv, data count: 59811
# complete apt-data-files/201609.csv, data count: 60995
# complete apt-data-files/201610.csv, data count: 71670
# complete apt-data-files/201611.csv, data count: 46722
# complete apt-data-files/201612.csv, data count: 36191
# complete apt-data-files/201701.csv, data count: 30126
# complete apt-data-files/201702.csv, data count: 41852
# complete apt-data-files/201703.csv, data count: 51241
# complete apt-data-files/201704.csv, data count: 47684
# complete apt-data-files/201705.csv, data count: 58833
# complete apt-data-files/201706.csv, data count: 62631
# complete apt-data-files/201707.csv, data count: 61708
# complete apt-data-files/201708.csv, data count: 45227
# complete apt-data-files/201709.csv, data count: 47247
# complete apt-data-files/201710.csv, data count: 39636
# complete apt-data-files/201711.csv, data count: 43933
# complete apt-data-files/201712.csv, data count: 40193
# complete apt-data-files/201801.csv, data count: 50677
# complete apt-data-files/201802.csv, data count: 43503
# complete apt-data-files/201803.csv, data count: 55215
# complete apt-data-files/201804.csv, data count: 35665
# complete apt-data-files/201805.csv, data count: 36816
# complete apt-data-files/201806.csv, data count: 38796
# complete apt-data-files/201807.csv, data count: 36512
# complete apt-data-files/201808.csv, data count: 56304
# complete apt-data-files/201809.csv, data count: 50858
# complete apt-data-files/201810.csv, data count: 43985
# complete apt-data-files/201811.csv, data count: 30734
# complete apt-data-files/201812.csv, data count: 26875
# complete apt-data-files/201901.csv, data count: 28402
# complete apt-data-files/201902.csv, data count: 26134
# complete apt-data-files/201903.csv, data count: 33393
# complete apt-data-files/201904.csv, data count: 32309
# complete apt-data-files/201905.csv, data count: 35097
# complete apt-data-files/201906.csv, data count: 38375
# complete apt-data-files/201907.csv, data count: 45214
# complete apt-data-files/201908.csv, data count: 41946
# complete apt-data-files/201909.csv, data count: 44028
# complete apt-data-files/201910.csv, data count: 64684
# complete apt-data-files/201911.csv, data count: 74303
# complete apt-data-files/201912.csv, data count: 70417
# complete apt-data-files/202001.csv, data count: 58604
# complete apt-data-files/202002.csv, data count: 81858
# complete apt-data-files/202003.csv, data count: 50516
# complete apt-data-files/202004.csv, data count: 43957
# complete apt-data-files/202005.csv, data count: 60240
# complete apt-data-files/202006.csv, data count: 105213
# complete apt-data-files/202007.csv, data count: 56616
# total data count: 4800528

# %%
# 생성 파일 로드 테스트
testD = pd.read_csv(data_files[0])
testD.info()
testD.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26054 entries, 0 to 26053
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   region           26054 non-null  object
#  1   region_sub       26054 non-null  object
#  2   apt_name         26054 non-null  object
#  3   apt_size         26054 non-null  float64
#  4   apt_floor        26054 non-null  int64
#  5   contract_date    26054 non-null  object
#  6   contract_price   26054 non-null  int64
#  7   completion_year  26054 non-null  int64
#  8   street_num       26054 non-null  object
#  9   street_name      26054 non-null  object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 2.0+ MB
#   region region_sub      apt_name  apt_size  apt_floor contract_date  \
# 0    강원도    강릉시 견소동          송정한신     84.94          5    2012-08-24
# 1    강원도    강릉시 견소동          송정한신     59.80         15    2012-08-27
# 2    강원도    강릉시 견소동          송정한신     59.80          1    2012-08-31
# 3    강원도    강릉시 견소동  송정해변신도브래뉴아파트     84.99          7    2012-08-08
# 4    강원도    강릉시 견소동  송정해변신도브래뉴아파트     84.99          9    2012-08-09
#
#    contract_price  completion_year street_num   street_name
# 0       130000000             1997        202   경강로2539번길 8
# 1        85000000             1997        202   경강로2539번길 8
# 2        60000000             1997        202   경강로2539번길 8
# 3       150000000             2005        289  경강로2539번길 22
# 4       165000000             2005        289  경강로2539번길 22
